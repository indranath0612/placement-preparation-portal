# %%
import sqlite3

conn = sqlite3.connect("database.db")
cur = conn.cursor()

cur.execute("""
CREATE TABLE users (
    username TEXT,
    password TEXT
)
""")

conn.commit()
conn.close()

# %%
import sqlite3

conn = sqlite3.connect("database.db")
cur = conn.cursor()

cur.execute("""
CREATE TABLE IF NOT EXISTS coding_questions (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    question TEXT
)
""")

conn.commit()
conn.close()

print("✅ coding_questions table created successfully")
# Out:
# ✅ coding_questions table created successfully

# %%
import sqlite3

questions = [
    # STRINGS
    "Reverse a string",
    "Check if a string is palindrome",
    "Count vowels in a string",
    "Count frequency of characters in a string",
    "Find first non-repeating character",
    "Check if two strings are anagrams",
    "Remove all whitespaces from a string",
    "Find length of string without using len()",
    "Convert string to uppercase without built-in functions",
    "Replace vowels with special characters",

    # NUMBERS
    "Find factorial of a number",
    "Check if number is prime",
    "Find GCD of two numbers",
    "Find LCM of two numbers",
    "Check Armstrong number",
    "Check perfect number",
    "Reverse an integer",
    "Sum of digits of a number",
    "Check if number is palindrome",
    "Check if number is power of two",

    # ARRAYS
    "Find largest element in array",
    "Find second largest element in array",
    "Find smallest element in array",
    "Remove duplicates from array",
    "Find missing number in array",
    "Find duplicate elements in array",
    "Rotate array by K positions",
    "Check if array is sorted",
    "Find intersection of two arrays",
    "Find union of two arrays",

    # SEARCH & SORT
    "Linear search implementation",
    "Binary search implementation",
    "Bubble sort",
    "Selection sort",
    "Insertion sort",
    "Merge two sorted arrays",
    "Find Kth largest element",
    "Find Kth smallest element",
    "Find majority element",
    "Maximum subarray sum (Kadane’s Algorithm)",

    # STACK & QUEUE
    "Implement stack using array",
    "Implement queue using array",
    "Check balanced parentheses",
    "Reverse stack",
    "Implement stack using linked list",
    "Implement queue using linked list",

    # LINKED LIST
    "Create a linked list",
    "Reverse a linked list",
    "Detect loop in linked list",
    "Find middle of linked list",
    "Merge two linked lists",
    "Check palindrome linked list",

    # RECURSION
    "Fibonacci using recursion",
    "Factorial using recursion",
    "Tower of Hanoi",
    "Generate all subsets of a string",
    "Generate permutations of a string",

    # MATRIX
    "Matrix multiplication",
    "Transpose of matrix",
    "Rotate matrix by 90 degrees",
    "Spiral traversal of matrix",
    "Search element in sorted matrix",

    # TREES
    "Implement binary search tree",
    "Inorder traversal of binary tree",
    "Preorder traversal of binary tree",
    "Postorder traversal of binary tree",
    "Height of binary tree",
    "Check if binary tree is balanced",

    # GRAPHS
    "Implement BFS",
    "Implement DFS",
    "Detect cycle in graph",
    "Topological sort",
    "Shortest path using BFS",

    # DYNAMIC PROGRAMMING
    "Longest common subsequence",
    "Longest increasing subsequence",
    "0/1 Knapsack problem",
    "Coin change problem",
    "Climbing stairs problem"
]

conn = sqlite3.connect("database.db")
cur = conn.cursor()

for q in questions:
    cur.execute(
        "INSERT INTO coding_questions (question) VALUES (?)",
        (q,)
    )

conn.commit()
conn.close()

print(f"✅ {len(questions)} coding questions inserted successfully")
# Out:
# ✅ 78 coding questions inserted successfully

# %%
import sqlite3, os

print("Notebook working directory:", os.getcwd())

conn = sqlite3.connect("database.db")
cur = conn.cursor()

cur.execute("SELECT COUNT(*) FROM coding_questions")
print("Questions in this DB:", cur.fetchone()[0])

conn.close()
# Out:
# Notebook working directory: C:\Users\KIIT0001\Desktop\placement_portal
# Questions in this DB: 78

# %%
import sqlite3

conn = sqlite3.connect("database.db")
cur = conn.cursor()

cur.execute("""
CREATE TABLE IF NOT EXISTS mcq (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    question TEXT,
    option1 TEXT,
    option2 TEXT,
    option3 TEXT,
    option4 TEXT,
    answer TEXT
)
""")

conn.commit()
conn.close()

print("✅ MCQ table ready")
# Out:
# ✅ MCQ table ready

# %%
import sqlite3

mcqs = [
    # Python Basics (1–20)
    ("What is Python?", "Snake", "Programming Language", "OS", "Game", "Programming Language"),
    ("Which is immutable?", "List", "Tuple", "Set", "Dictionary", "Tuple"),
    ("Which keyword defines a function?", "func", "define", "def", "function", "def"),
    ("Which data type stores key-value pairs?", "List", "Tuple", "Dictionary", "Set", "Dictionary"),
    ("Which loop is best when iterations are known?", "while", "for", "do-while", "loop", "for"),
    ("Which keyword is used to handle exceptions?", "try", "catch", "throw", "error", "try"),
    ("Which symbol is used for comments?", "//", "#", "/* */", "--", "#"),
    ("Which function returns length?", "count()", "len()", "size()", "length()", "len()"),
    ("Which operator is used for power?", "^", "**", "//", "%", "**"),
    ("Which is not a Python datatype?", "List", "Tuple", "Dictionary", "Array", "Array"),

    ("What is output of 5//2?", "2", "2.5", "3", "Error", "2"),
    ("Which keyword creates class?", "struct", "define", "class", "object", "class"),
    ("Which keyword stops loop?", "stop", "exit", "break", "end", "break"),
    ("Which keyword skips iteration?", "skip", "continue", "pass", "next", "continue"),
    ("Which is mutable?", "Tuple", "String", "List", "Integer", "List"),
    ("Which function converts string to int?", "int()", "str()", "float()", "eval()", "int()"),
    ("Which is correct file extension?", ".pt", ".py", ".python", ".pyt", ".py"),
    ("Which keyword deletes variable?", "remove", "del", "delete", "free", "del"),
    ("Which function prints output?", "print()", "show()", "display()", "output()", "print()"),
    ("Which block runs always?", "try", "except", "else", "finally", "finally"),

    # Data Structures (21–40)
    ("Which DS follows FIFO?", "Stack", "Queue", "Tree", "Graph", "Queue"),
    ("Which DS follows LIFO?", "Queue", "Stack", "Heap", "Graph", "Stack"),
    ("Which structure uses key-value?", "List", "Tuple", "Dictionary", "Set", "Dictionary"),
    ("Which DS allows duplicates?", "Set", "Dictionary", "List", "None", "List"),
    ("Which DS stores unique values?", "List", "Tuple", "Set", "Array", "Set"),
    ("Which DS is ordered?", "Set", "Dictionary", "List", "None", "List"),
    ("Stack pop removes from?", "Front", "Middle", "End", "Top", "Top"),
    ("Queue delete occurs at?", "Rear", "Middle", "Front", "Anywhere", "Front"),
    ("Which is linear DS?", "Tree", "Graph", "Array", "Heap", "Array"),
    ("Which DS is non-linear?", "Array", "Queue", "Stack", "Tree", "Tree"),

    ("Binary Search works on?", "Unsorted array", "Sorted array", "Any array", "List only", "Sorted array"),
    ("Worst case of linear search?", "O(1)", "O(log n)", "O(n)", "O(n log n)", "O(n)"),
    ("Worst case of binary search?", "O(1)", "O(n)", "O(log n)", "O(n²)", "O(log n)"),
    ("Bubble sort worst case?", "O(n)", "O(log n)", "O(n²)", "O(n log n)", "O(n²)"),
    ("Which sort is stable?", "Quick sort", "Heap sort", "Bubble sort", "Selection sort", "Bubble sort"),
    ("Which sort is fastest on average?", "Bubble", "Insertion", "Quick", "Selection", "Quick"),
    ("Which algorithm uses divide & conquer?", "Bubble", "Selection", "Quick", "Linear search", "Quick"),
    ("Which DS uses nodes?", "Array", "Linked List", "Set", "Tuple", "Linked List"),
    ("Which LL pointer stores address?", "data", "link", "value", "index", "link"),
    ("Which DS supports recursion internally?", "Queue", "Stack", "Heap", "Set", "Stack"),

    # OOPS + Misc (41–60)
    ("What is OOP?", "Procedure based", "Object based", "Functional", "None", "Object based"),
    ("Which is OOP principle?", "Compilation", "Inheritance", "Execution", "Debugging", "Inheritance"),
    ("Which supports code reuse?", "Polymorphism", "Inheritance", "Abstraction", "Encapsulation", "Inheritance"),
    ("Which hides implementation?", "Polymorphism", "Inheritance", "Abstraction", "Encapsulation", "Abstraction"),
    ("Which binds data and methods?", "Inheritance", "Encapsulation", "Abstraction", "Polymorphism", "Encapsulation"),
    ("Method overloading is?", "Compile time", "Run time", "Load time", "None", "Compile time"),
    ("Method overriding is?", "Compile time", "Run time", "Link time", "None", "Run time"),
    ("Which keyword refers parent?", "parent", "super", "this", "base", "super"),
    ("Constructor name same as?", "Object", "Class", "Function", "Method", "Class"),
    ("Destructor keyword?", "__delete__", "__free__", "__del__", "__remove__", "__del__"),

    # DB / OS / Web (61–80)
    ("Which DB uses tables?", "MongoDB", "Redis", "MySQL", "Neo4j", "MySQL"),
    ("Which SQL command fetches data?", "INSERT", "DELETE", "SELECT", "UPDATE", "SELECT"),
    ("Which SQL removes rows?", "DROP", "DELETE", "REMOVE", "CLEAR", "DELETE"),
    ("Which SQL creates table?", "MAKE", "ADD", "CREATE", "NEW", "CREATE"),
    ("Which DB is NoSQL?", "MySQL", "PostgreSQL", "MongoDB", "SQLite", "MongoDB"),
    ("Primary key allows?", "Duplicates", "Nulls", "Unique values", "Nothing", "Unique values"),
    ("Which HTTP method sends data?", "GET", "POST", "PUT", "DELETE", "POST"),
    ("Which port for HTTP?", "21", "80", "443", "22", "80"),
    ("Which is frontend?", "Flask", "Django", "HTML", "SQLite", "HTML"),
    ("Which is backend?", "CSS", "HTML", "Flask", "JS", "Flask"),

    # Aptitude / CS Basics (81–100)
    ("Which number system uses base 2?", "Decimal", "Octal", "Binary", "Hex", "Binary"),
    ("Which converts binary to decimal?", "Compiler", "Interpreter", "ALU", "CPU", "ALU"),
    ("CPU stands for?", "Central Program Unit", "Central Processing Unit", "Control Unit", "None", "Central Processing Unit"),
    ("Which memory is volatile?", "ROM", "HDD", "RAM", "SSD", "RAM"),
    ("Which is fastest memory?", "RAM", "Cache", "ROM", "HDD", "Cache"),
    ("Which OS is open source?", "Windows", "Linux", "macOS", "DOS", "Linux"),
    ("Which scheduling is preemptive?", "FCFS", "SJF", "Round Robin", "Priority", "Round Robin"),
    ("Which avoids deadlock?", "FCFS", "Banker’s Algorithm", "FIFO", "LIFO", "Banker’s Algorithm"),
    ("Which is not OS?", "Linux", "Windows", "Python", "Unix", "Python"),
    ("Which layer handles routing?", "Transport", "Network", "Session", "Data Link", "Network")
]

conn = sqlite3.connect("database.db")
cur = conn.cursor()

for q in mcqs:
    cur.execute("""
        INSERT INTO mcq (question, option1, option2, option3, option4, answer)
        VALUES (?, ?, ?, ?, ?, ?)
    """, q)

conn.commit()
conn.close()

print(f"✅ {len(mcqs)} UNIQUE MCQs inserted successfully")
# Out:
# ✅ 70 UNIQUE MCQs inserted successfully
